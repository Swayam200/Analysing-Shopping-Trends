# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('shopping_trends_updated.csv')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df['Item Purchased'].unique().shape
# Out:
# (25,)

# %% [markdown]
# ## 1.what is the overall distribution of customer age in dataset

# %%
df['Age'].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(44.06846153846154)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Age category']=pd.cut(df['Age'],bins=[0,15,18,30,50,70],labels=['child','teen','young adult','adult','old'])
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
fig=px.histogram(df,y='Age', x='Age category')
fig.show()
# Out:
# <div>                            <div id="100d026a-8fe5-4153-a0c6-b799690d8e7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("100d026a-8fe5-4153-a0c6-b799690d8e7c")) {                    Plotly.newPlot(                        "100d026a-8fe5-4153-a0c6-b799690d8e7c",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Age category=%{x}\u003cbr\u003esum of Age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["old","young adult","adult","young adult","adult","adult","old","young adult","young adult","old","old","young adult","old","old","old","old","young adult","old","old"
# ...

# %% [markdown]
# ## 2.How does the purchase amount vary across different product categories

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age category'],
#       dtype='object')

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df.groupby('Category')['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# ## 3.which gender has highest number of purchase

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age category'],
#       dtype='object')

# %%
sns.barplot(df,x='Gender',y='Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase Amount (USD)'>

# %%
df.groupby('Gender')['Purchase Amount (USD)'].value_counts()
# Out:
# Gender  Purchase Amount (USD)
# Female  82                       24
#         32                       22
#         52                       22
#         45                       21
#         70                       21
#                                  ..
# Male    61                       23
#         65                       23
#         70                       23
#         52                       22
#         87                       22
# Name: count, Length: 162, dtype: int64

# %% [markdown]
# ## 4.what is most commonly purchased item in all categories

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age category'],
#       dtype='object')

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
sns.barplot(df['Gender'])
# Out:
# <Axes: ylabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%3.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
ax=df['Category'].value_counts().plot(kind='bar',rot=0)
for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.25,p.get_height()+1),ha='center')
plt.xlabel("Category",weight='bold')
plt.ylabel("occurence")
plt.show()

# %%
 df['Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
 df['Season'].value_counts().plot(kind='pie',explode=(0,0.2,0.2,0.2),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'Age category'],
#       dtype='object')

# %%
df['Subscription Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Subscription Status'>

# %% [markdown]
# ## 8.which payment meathod is most popular among all

# %%
df.groupby('Payment Method')['Purchase Amount (USD)'].mean().sort_values(ascending=False)
# Out:
# Payment Method
# Debit Card       60.915094
# Credit Card      60.074516
# Bank Transfer    59.712418
# Cash             59.704478
# PayPal           59.245199
# Venmo            58.949527
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(x='Payment Method',y='Purchase Amount (USD)',data=df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='Purchase Amount (USD)'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
num_fea=df[["Age","Purchase Amount (USD)","Review Rating","Previous Purchases"]]
num_fea
# Out:
#       Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# 0      55                     53            3.1                  14
# 1      19                     64            3.1                   2
# 2      50                     73            3.1                  23
# 3      21                     90            3.5                  49
# 4      45                     49            2.7                  31
# ...   ...                    ...            ...                 ...
# 3895   40                     28            4.2                  32
# 3896   52                     49            4.5                  41
# 3897   46                     33            2.9                  24
# 3898   44                     77            3.8                  24
# 3899   52                     81            3.1                  33
#
# [3900 rows x 4 columns]

# %%
cor=num_fea.corr()
cor
# Out:
#                             Age  Purchase Amount (USD)  Review Rating  \
# Age                    1.000000              -0.010424      -0.021949
# Purchase Amount (USD) -0.010424               1.000000       0.030776
# Review Rating         -0.021949               0.030776       1.000000
# Previous Purchases     0.040445               0.008063       0.004229
#
#                        Previous Purchases
# Age                              0.040445
# Purchase Amount (USD)            0.008063
# Review Rating                    0.004229
# Previous Purchases               1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >
